# %% [markdown]
# <a href="https://colab.research.google.com/github/lacastanop/se-alesys/blob/main/3_Operaciones_de_se%C3%B1ales_continuas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Los ejercicios se ubican a lo ultimo de los cuadernillos*

# %% [markdown]
# # Operaciones básicas sobre señales
#
# Las operaciones como la superposición, el cambio temporal y el escalamiento, se utilizan para construir señales con una estructura más compleja.
#
# Se introduce un conjunto de operaciones elementales que se utilizan frecuentemente en el procesamiento de señales.

# %% [markdown]
# ### Superposición
#
# La superposición $x(t)$ de dos señales $x_1(t)$ and $x_2(t)$ está dada por:
#
# \begin{equation}
# x(t) = A \cdot x_1(t) + B \cdot x_2(t)
# \end{equation}
#
# con los pesos complejos $A, B \in \mathbb{C}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra la superposición de dos señales armónicas $x(t) = A \cdot \cos(\omega_1 t) + B \cdot \cos(\omega_2 t)$ con pesos $A$, $B$ y frecuencia angular $\omega_1$ y $\omega_2$.

# %%
# %matplotlib inline
import sympy as sym

t = sym.symbols('t', real=True)#se declara la variable simbólica t

#parámetros de las funciones cos
A = .3
om1 = 3
B = .5
om2 = 5

#operación superposición en sympy
x = A*sym.cos(om1*t) + B*sym.cos(om2*t)
#se grafica la señal resultante
sym.plot(x, (t,-5,5), ylim=[-1.2, 1.2], ylabel=r'$x(t)$');

# %% [markdown]
# ### Desplazamiento temporal
#
# El desplazamiento temporal de una señal $s(t)$ en un instante de tiempo $\tau$ es una operación frecuentemente aplicada en el procesamiento de señales. Por ejemplo, para modelar la propagación de señales desde un actuador a un sensor.
#
# El desplazamiento de la señal $x(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(t-\tau)
# \end{equation}
#
# con $\tau \in \mathbb{R}$. La señal $s(t)$ es:
#
# * desplazada hacia la derecha (*retrasada*) para $\tau > 0$
# * desplazada hacia la izquierda para $\tau < 0$

# %% [markdown]
# **Ejemplo**
#
# Para ilustrar el cambio temporal de señales, la construcción de una señal escalera por una superposición de desplazamiento se define como:
#
# \begin{equation}
# x(t) = \text{rect}\left(t - \frac{1}{2} \right) + \frac{2}{3} \cdot \text{rect}\left(t-\frac{3}{2} \right) + \frac{1}{3} \cdot \text{rect} \left(t-\frac{5}{2} \right)
# \end{equation}

# %%
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')
#los rect desplazados se acoplan con escalamientos diferentes
x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)
sym.plot(x, (t, -1, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');

# %% [markdown]
# **Ejercicio**
#
# * Agregar otro escalón al principio de la señal escalera modificando el ejemplo anterior.

# %%
#Ejercicio 1
#Modificar el ejemplo x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)

import sympy as sym
t = sym.symbols('t') # Definición de la variable simbólica

# Definición de la función escalón (rect)
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)

# Graficar la función escalón básica (rect)
sym.plot(rect, xlim=[-2, 2], ylabel=r'rect(t)')

# Modificación: Cuatro escalones al principio de la señal escalera
# Los rect desplazados y escalados se acoplan para crear la señal escalera
x = rect.subs(t, t + 1.5) + 0.8*rect.subs(t, t +0.5) + rect.subs(t, t - 0.5) + 2/3 * rect.subs(t, t - 3/2) + 1/3 * rect.subs(t, t - 5/2)

# Graficar la señal escalera modificada
sym.plot(x, (t, -2, 5), ylim=[-0.2, 2], ylabel='$x(t)$');

# %% [markdown]
# ### Escalamiento temporal
#
# El escalamiento temporal de una señal $s(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(a \cdot t)
# \end{equation}
#
# con $a \in \mathbb{R}$. La señal $s(t)$ es
#
# * estirada para $0 < a < 1$
# * comprimida $a > 1$
# * invertida y escalada para $a < 0$
#
# Una aplicación de escalado temporal en el procesamiento de la señal es la escala de las señales estándar y el modelado del [efecto Doppler](https://en.wikipedia.org/wiki/Doppler_effect).

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el escalamiento de una señal escalera $y(t) = x(a \cdot t)$.

# %%
a = sym.symbols('a', real=True)
y = x.subs(t, a*t)

px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray')
py = sym.plot(y.subs(a,1/2), (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)#se extiende los gráficos sobre una misma figura
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Modifique el ejemplo anterior para que la señal se comprima.
# * Modifique el ejemplo anterior para que la señal se escale y se invierta. ¿Qué factor de escala `a`da como resultado un       estiramiento/compresión en este contexto?

# %%
#Ejercicio 2
#Para comprimir la señal, multiplicamos la variable t por un factor mayor que 1.
#Para escalar e invertir la señal, multiplicamos t por un valor negativo. Esto estira o comprime la señal y la invierte.

import sympy as sym

# Definición de la variable simbólica
t = sym.symbols('t', real=True)
a = sym.symbols('a', real=True)

# Suponemos que 'x' es la señal que quieres modificar.
# Ejemplo de 'x', señal escalera que trabajada antes:
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
x = rect.subs(t, t + 1.5) + rect.subs(t, t + 0.5) + rect.subs(t, t - 0.5) + 2/3 * rect.subs(t, t - 3/2) + 1/3 * rect.subs(t, t - 5/2)

# Comprimir la señal
y_comprimida = x.subs(t, 2*t)  # Comprimir la señal con un factor de 2

# Escalar e invertir la señal
y_invertida = x.subs(t, -1/2 * t)  # Invertir y escalar con un factor de -1/2

# Graficar la señal original y la señal comprimida
px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.5], ylabel=r'$y(t)$', show=False, line_color='gray', label='Original')
py_comprimida = sym.plot(y_comprimida, (t, -7, 7), ylim=[-0.2, 1.5], ylabel=r'$y(t)$', show=False, line_color='blue', label='Comprimida')
py_invertida = sym.plot(y_invertida, (t, -7, 7), ylim=[-0.2, 1.5], ylabel=r'$y(t)$', show=False, line_color='red', label='Escalada e Invertida')

# Extender y mostrar los gráficos en la misma figura
px.extend(py_comprimida)
px.extend(py_invertida)
px[0].line_color = 'gray'  # Color de la señal original
px.legend = True  # Mostrar leyenda
px.show()

# %% [markdown]
# ### Desplazamiento Temporal

# %% [markdown]
# El desplazamiento temporal de una señal $s(t)$ está definido como
#
# \begin{equation}
# x(t) = s(\tau - t)
# \end{equation}
#
# para $\tau \in \mathbb{R}$. Como $s(\tau - t) = s(- (t - \tau))$ la operación espejo también se puede representar como una inversión temporal de la señal $s(t)$ seguida por un desplazamiento de $\tau$ de la señal invertida. Para $\tau = 0$ este resultado es solo una inversión temporal de la señal.
#
# La operación de cambio temporal puede interpretarse geométricamente como un reflejo de la señal $s(t)$ en el eje vertical $t=\frac{\tau}{2}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el cambio temporal $y(t) = x(\tau - t)$ de la señal escalera $x(t)$ anteriormente introducida.

# %%
tau =-1
y = x.subs(t, tau - t)

px=sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', line_color='gray', show=False)
py=sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Para que valor de $\tau$, ¿la señal comienza en $t=0$?
# * Realice un cambio temporal dividiendo en dos operaciones consecutivas: (i) Inversión temporal y (ii) Desplazamiento temporal.

# %%
#Para encontrar el valor de 𝜏 que hace que la señal comience en 𝑡 = 0.
#necesitamos ajustar 𝜏 de manera que la señal 𝑥 sea activada en t=0.
#Resolvemos para 𝜏 en la expresión x(τ−t) tal que la primera transición de 𝑥 ocurra en 𝑡=0

import sympy as sym

# Definición de la variable simbólica
t = sym.symbols('t', real=True)
tau = sym.symbols('tau', real=True)

# Definición de la función escalón (rect)
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
x = rect.subs(t, t + 1.5) + rect.subs(t, t + 0.5) + rect.subs(t, t - 0.5) + 2/3 * rect.subs(t, t - 3/2) + 1/3 * rect.subs(t, t - 5/2)

y_invertida = x.subs(t, -t) #Cambio Temporal: Inversión Temporal
y_transformada = y_invertida.subs(t, t + tau) #Desplazamiento Temporal después de Inversión

# Valor de tau para que la señal comience en t=0
# Si la señal comienza en t=0 después del desplazamiento temporal, necesitamos calcular tau.
# Esto puede variar según el comportamiento exacto de x(t), así que para el ejemplo se usará un valor aproximado.

# Graficar la señal original, invertida y transformada
px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$x(t)$', line_color='gray', show=False, label='Original')
py_invertida = sym.plot(y_invertida, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$x(-t)$', show=False, line_color='blue', label='Invertida')
py_transformada = sym.plot(y_transformada.subs(tau, 1.5), (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$x(-t + \tau)$', show=False, line_color='red', label='Transformada')

# Extender y mostrar los gráficos
px.extend(py_invertida)
px.extend(py_transformada)
px.legend = True
px.show()

# %% [markdown]
# **Copyright**
#
# The notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebook for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: *Signals and Systems* by Sascha Spors.
